# %% [markdown]
# ### 1. Print numbers from 1 to 10 using a for loop.

# %%
# Write your answer here

# %% [markdown]
# ### 2. Print numbers from 1 to 20.

# %%
# Write your answer here

# %% [markdown]
# ### 3. Print numbers from 10 to 1 (reverse order).

# %%
# Write your answer here

# %% [markdown]
# ### 4. Print even numbers from 1 to 20.

# %%
# Write your answer here

# %% [markdown]
# ### 5. Print odd numbers from 1 to 20.

# %%
# Write your answer here

# %% [markdown]
# ### 6. Print numbers from 0 to 50 with step 5.

# %%
# Write your answer here

# %% [markdown]
# ### 7. Print numbers from 100 to 0 with step -10.

# %%
# Write your answer here

# %% [markdown]
# ### 8. Print all multiples of 3 between 1 and 30.

# %%
# Write your answer here

# %% [markdown]
# ### 9. Print all multiples of 7 between 1 and 50.

# %%
# Write your answer here

# %% [markdown]
# ### 10. Print numbers from 1 to 100 that are divisible by 5.

# %%
# Write your answer here

# %% [markdown]
# ### 11. Find the sum of numbers from 1 to 10 using a for loop.

# %%
# Write your answer here

# %% [markdown]
# ### 12. Find the sum of numbers from 1 to 100.

# %%
# Write your answer here

# %% [markdown]
# ### 13. Find the product of numbers from 1 to 5.

# %%
# Write your answer here

# %% [markdown]
# ### 14. Find the sum of even numbers from 1 to 20.

# %%
# Write your answer here

# %% [markdown]
# ### 15. Count how many numbers are divisible by 3 between 1 and 50.

# %%
# Write your answer here

# %% [markdown]
# ### 16. Print '*' 5 times using a for loop.

# %%
# Write your answer here

# %% [markdown]
# ### 17. Print numbers from 1 to 5 (each on new line).

# %%
# Write your answer here

# %% [markdown]
# ### 18. Print numbers 2, 4, 6, 8, 10 using a for loop.

# %%
# Write your answer here

# %% [markdown]
# ### 19. Print numbers from 1 to 5, each number printed 3 times.

# %%
# Write your answer here

# %% [markdown]
# ### 20. Print numbers from 1 to 5 and display their squares.

# %%
# Write your answer here
